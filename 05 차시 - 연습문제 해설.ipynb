# %% [markdown]
# # 05 차시 - 연습문제 해설

# %% [markdown]
# 다음의 파이썬 코드에서 2019-01-02 ~ 2019-01-07 4일간의 평균 가격(종가 close 기준)을 구하는 코드를 작성하시오

# %%
stock = {
  'name': '삼성전자',
  'market': '코스피',
  'close': [
    ('2019-01-02', 38750),
    ('2019-01-03', 37600),
    ('2019-01-04', 37450),
    ('2019-01-07', 38750),
  ],
  'market-cap': 2766994,
  'PER': 8.55,
}

# %%
stock
# Out:
# {'name': '삼성전자',
#  'market': '코스피',
#  'close': [('2019-01-02', 38750),
#   ('2019-01-03', 37600),
#   ('2019-01-04', 37450),
#   ('2019-01-07', 38750)],
#  'market-cap': 2766994,
#  'PER': 8.55}

# %%
stock['close']
# Out:
# [('2019-01-02', 38750),
#  ('2019-01-03', 37600),
#  ('2019-01-04', 37450),
#  ('2019-01-07', 38750)]

# %%
for x in stock['close']:
    print(x)
# Out:
# ('2019-01-02', 38750)
# ('2019-01-03', 37600)
# ('2019-01-04', 37450)
# ('2019-01-07', 38750)

# %%
for x in stock['close']:
    print(x[1])
# Out:
# 38750
# 37600
# 37450
# 38750

# %%
lst = []

for x in stock['close']:
    lst.append(x[1])
lst
# Out:
# [38750, 37600, 37450, 38750]

# %%
sum(lst)
# Out:
# 152550

# %%
len(lst)
# Out:
# 4

# %%
sum(lst) / len(lst)
# Out:
# 38137.5
