# %% [markdown]
# # 4차시 연습문제 해설
#
# 1. "Hello, Python" 이란 간단한 문자열 출력하기
# 1. "3.14"라는 문자열을 float 타입으로 바꾸어 변수에 저장하기
# 1. 두 변수에 수치값을 넣고 사칙 연산을 포함하여 다양한 연산 수행하기
# 1. 임의의 긴 문자열에서 마지막 3글자를 추출하는 예제 코드 작성하기
# 1. 임의의 긴 문자열을 공백 기준으로 잘라 단어의 수를 출력하는 예제 코드 작성하기

# %%
# 1. "Hello, Python" 이란 간단한 문자열 출력하기

# %%
print('"Hello, Python"')
# Out:
# "Hello, Python"

# %%
print("\"Hello, Python\"")
# Out:
# "Hello, Python"

# %%
# 2. "3.14"라는 문자열을 float 타입으로 바꾸어 변수에 저장하기

# %%
s = '3.14'
f = float(s)
f
# Out:
# 3.14

# %%
type(f)
# Out:
# float

# %%
# 3. 두 변수에 수치값을 넣고 사칙 연산을 포함하여 다양한 연산 수행하기

# %%
a = 10
b = 30

a + b, a * b , a / b, a - b
# Out:
# (40, 300, 0.3333333333333333, -20)

# %%
# 4. 임의의 긴 문자열에서 마지막 3글자를 추출하는 예제 코드 작성하기

# %%
s = 'Hello, Python'

s[-3:]
# Out:
# 'hon'

# %%
# 5. 임의의 긴 문자열을 공백 기준으로 잘라 단어의 수를 출력하는 예제 코드 작성하기

# %%
s = '임의의 긴 문자열을 공백 기준으로 잘라 단어의 수를 출력하는 예제 코드 작성하기'

len(s.split())
# Out:
# 12
