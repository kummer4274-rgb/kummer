# %% [markdown]
# # 10 차시 - 본문 실습

# %%
import pandas as pd

s = pd.Series([7, 0, -3, 8, 1])
s
# Out:
# 0    7
# 1    0
# 2   -3
# 3    8
# 4    1
# dtype: int64

# %%
data = [7, 0, -3, 8, 1]
inx = ['A', 'B', 'C', 'D', 'E']

s = pd.Series(data, index=inx)
s
# Out:
# A    7
# B    0
# C   -3
# D    8
# E    1
# dtype: int64

# %%
s[0]
# Out:
# 7

# %%
s['A']
# Out:
# 7

# %%
## pandas 핵심 자료구조 - DataFrame
# dict로 부터 생성하기

data = {
  'A' : [10, 20, 30], 
  'B' : [40, 50, 60], 
  'C' : [70, 80, 90],
}

df = pd.DataFrame(data, index = [1, 2, 3])
df
# Out:
#     A   B   C
# 1  10  40  70
# 2  20  50  80
# 3  30  60  90

# %%
import pandas as pd

values = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]
index = [1,2,3]
columns = ['A', 'B', 'C']

df = pd.DataFrame(values, index=index, columns=columns)
df
# Out:
#     A   B   C
# 1  10  20  30
# 2  40  50  60
# 3  70  80  90

# %%
df.head(2) # 처음 2개 행
# Out:
#     A   B   C
# 1  10  20  30
# 2  40  50  60

# %%
df.tail(2) # 뒷부분 2개 행
# Out:
#     A   B   C
# 2  40  50  60
# 3  70  80  90

# %%
df[df.A >= 50] # 컬럼 A가 50 이상인 행을 조회
# Out:
#     A   B   C
# 3  70  80  90

# %%
# 정수 인덱싱
df.iloc[1:3]
# Out:
#     A   B   C
# 2  40  50  60
# 3  70  80  90

# %%
df.iloc[:, [1, 0]]
# Out:
#     B   A
# 1  20  10
# 2  50  40
# 3  80  70

# %%
# 레이블 인덱싱
df.loc[:,'A':'B']
# Out:
#     A   B
# 1  10  20
# 2  40  50
# 3  70  80

# %%
df.loc[df['B'] > 40, ['B', 'A']]
# Out:
#     B   A
# 2  50  40
# 3  80  70

# %%
df['C'] # 혹은 df.C
# Out:
# 1    30
# 2    60
# 3    90
# Name: C, dtype: int64

# %%
df[['C','A','B']] # 특정 컬럼만 지정해서 순서대로 읽기
# Out:
#     C   A   B
# 1  30  10  20
# 2  60  40  50
# 3  90  70  80

# %%
# 리스트로 부터 생성하기

values = [
  ['2019-10', 17213058, 17695770, 7691742, 5811352, 4966225],
  ['2019-11', 15767139, 18344561, 9932071, 5760428, 2329041],
  ['2019-12', 14289812, 14807176, 12660962, 6626276, 8914585],
  ['2020-01', 4972074, 11391979, 9596229, 5834792, 3650543],
  ['2020-02', 23522875, 4874541, 4993788, 2757485, 5236393],
  ['2020-03', 25040023, 17347968, 6374132, 3168658, 6835417],
]

df = pd.DataFrame(values)
df
# Out:
#          0         1         2         3        4        5
# 0  2019-10  17213058  17695770   7691742  5811352  4966225
# 1  2019-11  15767139  18344561   9932071  5760428  2329041
# 2  2019-12  14289812  14807176  12660962  6626276  8914585
# 3  2020-01   4972074  11391979   9596229  5834792  3650543
# 4  2020-02  23522875   4874541   4993788  2757485  5236393
# 5  2020-03  25040023  17347968   6374132  3168658  6835417

# %%
# DataFrame을 생성하면서 컬럼 지정하기

cols = ['날짜', '삼성전자', 'LG전자', '현대자동차', 'SK텔레콤', 'KT']
df = pd.DataFrame(values, columns=cols)
df
# Out:
#         날짜      삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 0  2019-10  17213058  17695770   7691742  5811352  4966225
# 1  2019-11  15767139  18344561   9932071  5760428  2329041
# 2  2019-12  14289812  14807176  12660962  6626276  8914585
# 3  2020-01   4972074  11391979   9596229  5834792  3650543
# 4  2020-02  23522875   4874541   4993788  2757485  5236393
# 5  2020-03  25040023  17347968   6374132  3168658  6835417

# %%
# 딕셔너리로 부터 생성
values = {
    '날짜': ['2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03'],
    '삼성전자': [17213058, 15767139, 14289812,  4972074, 23522875, 25040023], 
    'LG전자': [17695770, 18344561, 14807176, 11391979,  4874541, 17347968],
    '현대자동차': [ 7691742,  9932071, 12660962,  9596229,  4993788,  6374132],
    'SK텔레콤' : [5811352, 5760428, 6626276, 5834792, 2757485, 3168658],
    'KT': [4966225, 2329041, 8914585, 3650543, 5236393, 6835417],
}

df = pd.DataFrame(values)
df
# Out:
#         날짜      삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 0  2019-10  17213058  17695770   7691742  5811352  4966225
# 1  2019-11  15767139  18344561   9932071  5760428  2329041
# 2  2019-12  14289812  14807176  12660962  6626276  8914585
# 3  2020-01   4972074  11391979   9596229  5834792  3650543
# 4  2020-02  23522875   4874541   4993788  2757485  5236393
# 5  2020-03  25040023  17347968   6374132  3168658  6835417

# %%
dates = pd.to_datetime(['2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03'])
dates
# Out:
# DatetimeIndex(['2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
# 딕셔너리로 부터 생성
# 생성하면서 인덱스를 지정
import pandas as pd

values = {
    '삼성전자': [17213058, 15767139, 14289812,  4972074, 23522875, 25040023], 
    'LG전자': [17695770, 18344561, 14807176, 11391979,  4874541, 17347968],
    '현대자동차': [ 7691742,  9932071, 12660962,  9596229,  4993788,  6374132],
    'SK텔레콤' : [5811352, 5760428, 6626276, 5834792, 2757485, 3168658],
    'KT': [4966225, 2329041, 8914585, 3650543, 5236393, 6835417],
}

dates = pd.to_datetime(['2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03'])
df = pd.DataFrame(values, index=dates)
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 2019-10-01  17213058  17695770   7691742  5811352  4966225
# 2019-11-01  15767139  18344561   9932071  5760428  2329041
# 2019-12-01  14289812  14807176  12660962  6626276  8914585
# 2020-01-01   4972074  11391979   9596229  5834792  3650543
# 2020-02-01  23522875   4874541   4993788  2757485  5236393
# 2020-03-01  25040023  17347968   6374132  3168658  6835417

# %%
# 인덱스(index)
df.index
# Out:
# DatetimeIndex(['2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
# 열(column)
df.columns
# Out:
# Index(['삼성전자', 'LG전자', '현대자동차', 'SK텔레콤', 'KT'], dtype='object')

# %%
# 값 (2차원 배열)
df.values
# Out:
# array([[17213058, 17695770,  7691742,  5811352,  4966225],
#        [15767139, 18344561,  9932071,  5760428,  2329041],
#        [14289812, 14807176, 12660962,  6626276,  8914585],
#        [ 4972074, 11391979,  9596229,  5834792,  3650543],
#        [23522875,  4874541,  4993788,  2757485,  5236393],
#        [25040023, 17347968,  6374132,  3168658,  6835417]], dtype=int64)

# %% [markdown]
# ## df.dtypes
# df.dtypes - 각 컬럼의 데이터 타입을 확인

# %%
# 열(column)과 타입
df.dtypes
# Out:
# 삼성전자     int64
# LG전자     int64
# 현대자동차    int64
# SK텔레콤    int64
# KT       int64
# dtype: object

# %% [markdown]
# ## DataFrame 데이터 살펴보기

# %%
# 전체 살펴보기
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 2019-10-01  17213058  17695770   7691742  5811352  4966225
# 2019-11-01  15767139  18344561   9932071  5760428  2329041
# 2019-12-01  14289812  14807176  12660962  6626276  8914585
# 2020-01-01   4972074  11391979   9596229  5834792  3650543
# 2020-02-01  23522875   4874541   4993788  2757485  5236393
# 2020-03-01  25040023  17347968   6374132  3168658  6835417

# %% [markdown]
# len(df) - 행(row)의 수

# %%
# 행(row) 수 (df.shape[0] 와 동일하다)
len(df)
# Out:
# 6

# %%
# 컬럼 살펴보기
df.삼성전자
# Out:
# 2019-10-01    17213058
# 2019-11-01    15767139
# 2019-12-01    14289812
# 2020-01-01     4972074
# 2020-02-01    23522875
# 2020-03-01    25040023
# Name: 삼성전자, dtype: int64

# %%
# 컬럼(Series) 살펴보기
df['삼성전자']
# Out:
# 2019-10-01    17213058
# 2019-11-01    15767139
# 2019-12-01    14289812
# 2020-01-01     4972074
# 2020-02-01    23522875
# 2020-03-01    25040023
# Name: 삼성전자, dtype: int64

# %% [markdown]
# DataFrame 데이터 살펴보기
# * df.head() - 앞 부분 보기
# * df.tail() - 뒷 부분 보기

# %%
# 앞 부분 보기 (기본 5행)
df.head(2)
# Out:
#                 삼성전자      LG전자    현대자동차    SK텔레콤       KT
# 2019-10-01  17213058  17695770  7691742  5811352  4966225
# 2019-11-01  15767139  18344561  9932071  5760428  2329041

# %%
# 뒷 부분 보기 (기본 5행)
df.tail(2)
# Out:
#                 삼성전자      LG전자    현대자동차    SK텔레콤       KT
# 2020-02-01  23522875   4874541  4993788  2757485  5236393
# 2020-03-01  25040023  17347968  6374132  3168658  6835417

# %% [markdown]
# ## 컬럼 지정하기

# %%
df.KT
# Out:
# 2019-10-01    4966225
# 2019-11-01    2329041
# 2019-12-01    8914585
# 2020-01-01    3650543
# 2020-02-01    5236393
# 2020-03-01    6835417
# Name: KT, dtype: int64

# %%
df['KT']
# Out:
# 2019-10-01    4966225
# 2019-11-01    2329041
# 2019-12-01    8914585
# 2020-01-01    3650543
# 2020-02-01    5236393
# 2020-03-01    6835417
# Name: KT, dtype: int64

# %%
df.values
# Out:
# array([[17213058, 17695770,  7691742,  5811352,  4966225],
#        [15767139, 18344561,  9932071,  5760428,  2329041],
#        [14289812, 14807176, 12660962,  6626276,  8914585],
#        [ 4972074, 11391979,  9596229,  5834792,  3650543],
#        [23522875,  4874541,  4993788,  2757485,  5236393],
#        [25040023, 17347968,  6374132,  3168658,  6835417]], dtype=int64)

# %%
df.KT.values
# Out:
# array([4966225, 2329041, 8914585, 3650543, 5236393, 6835417], dtype=int64)

# %% [markdown]
# ## 데이터 요약 - df.describe()

# %%
# 모든 컬럼의 기술통계(descriptive stats) 값
df.describe()
# Out:
#                삼성전자          LG전자         현대자동차         SK텔레콤            KT
# count  6.000000e+00  6.000000e+00  6.000000e+00  6.000000e+00  6.000000e+00
# mean   1.680083e+07  1.407700e+07  8.541487e+06  4.993165e+06  5.322034e+06
# std    7.218495e+06  5.185259e+06  2.757606e+06  1.610006e+06  2.327341e+06
# min    4.972074e+06  4.874541e+06  4.993788e+06  2.757485e+06  2.329041e+06
# 25%    1.465914e+07  1.224578e+07  6.703534e+06  3.816600e+06  3.979464e+06
# 50%    1.649010e+07  1.607757e+07  8.643986e+06  5.785890e+06  5.101309e+06
# 75%    2.194542e+07  1.760882e+07  9.848110e+06  5.828932e+06  6.435661e+06
# max    2.504002e+07  1.834456e+07  1.266096e+07  6.626276e+06  8.914585e+06

# %% [markdown]
# ## 인덱스 기반 조회
# * loc: 라벨 인덱싱
# * iloc: 정수 인덱싱

# %%
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 2019-10-01  17213058  17695770   7691742  5811352  4966225
# 2019-11-01  15767139  18344561   9932071  5760428  2329041
# 2019-12-01  14289812  14807176  12660962  6626276  8914585
# 2020-01-01   4972074  11391979   9596229  5834792  3650543
# 2020-02-01  23522875   4874541   4993788  2757485  5236393
# 2020-03-01  25040023  17347968   6374132  3168658  6835417

# %%
# 특정 날짜를 지정
df.loc['2020-01-01']
# Out:
# 삼성전자      4972074
# LG전자     11391979
# 현대자동차     9596229
# SK텔레콤     5834792
# KT        3650543
# Name: 2020-01-01 00:00:00, dtype: int64

# %%
# 컬럼을 추출

df.loc[:, ['SK텔레콤','KT']]
# Out:
#               SK텔레콤       KT
# 2019-10-01  5811352  4966225
# 2019-11-01  5760428  2329041
# 2019-12-01  6626276  8914585
# 2020-01-01  5834792  3650543
# 2020-02-01  2757485  5236393
# 2020-03-01  3168658  6835417

# %%
# 날짜의 범위를 지정
df.loc['20200101': '20200229',['SK텔레콤','KT']]
# Out:
#               SK텔레콤       KT
# 2020-01-01  5834792  3650543
# 2020-02-01  2757485  5236393

# %%
df.loc[:, ['삼성전자','KT']] # 모든 로우, 컬럼 '삼성전자','KT' 선택
# Out:
#                 삼성전자       KT
# 2019-10-01  17213058  4966225
# 2019-11-01  15767139  2329041
# 2019-12-01  14289812  8914585
# 2020-01-01   4972074  3650543
# 2020-02-01  23522875  5236393
# 2020-03-01  25040023  6835417

# %%
# 특정 행을 지정 (결과는 Series가 됩니다)
df.loc['20200101', ['SK텔레콤','KT']]
# Out:
# SK텔레콤    5834792
# KT       3650543
# Name: 2020-01-01 00:00:00, dtype: int64

# %%
# 특정 값 하나를 얻습니다.
df.loc['20200101', '현대자동차']
# Out:
# 9596229

# %%
# 특정 값 하나를 얻습니다. (동일한 표현입니다. 값 1개만 찾을때 사용하며 속도가 더 빠릅니다)
df.at['20200101', '현대자동차']
# Out:
# 9596229

# %%
df.iloc[1] # 1 행(두번째 행)
# Out:
# 삼성전자     15767139
# LG전자     18344561
# 현대자동차     9932071
# SK텔레콤     5760428
# KT        2329041
# Name: 2019-11-01 00:00:00, dtype: int64

# %%
df.iloc[1:3] # 1~2행
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 2019-11-01  15767139  18344561   9932071  5760428  2329041
# 2019-12-01  14289812  14807176  12660962  6626276  8914585

# %%
#첫번째 행(row), 첫번째 열(column)
df.iloc[0,0]
# Out:
# 17213058

# %%
# 처음 4개 행(row), 처음 2개 열(column)
df.iloc[0:4, :2]
# Out:
#                 삼성전자      LG전자
# 2019-10-01  17213058  17695770
# 2019-11-01  15767139  18344561
# 2019-12-01  14289812  14807176
# 2020-01-01   4972074  11391979

# %%
# 특정 행을 지정하고, 컬럼의 범위를 지정
df.iloc[[5, 2], 1:3]
# Out:
#                 LG전자     현대자동차
# 2020-03-01  17347968   6374132
# 2019-12-01  14807176  12660962

# %% [markdown]
# # 컬럼 연산
# * 컬럼 추가
# * 컬럼간 사칙연산
# * 컬럼 삭제 (del)

# %%
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 2019-10-01  17213058  17695770   7691742  5811352  4966225
# 2019-11-01  15767139  18344561   9932071  5760428  2329041
# 2019-12-01  14289812  14807176  12660962  6626276  8914585
# 2020-01-01   4972074  11391979   9596229  5834792  3650543
# 2020-02-01  23522875   4874541   4993788  2757485  5236393
# 2020-03-01  25040023  17347968   6374132  3168658  6835417

# %%
# 컬럼 추가

df['텔레콤_합계'] = 0  
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT  텔레콤_합계
# 2019-10-01  17213058  17695770   7691742  5811352  4966225       0
# 2019-11-01  15767139  18344561   9932071  5760428  2329041       0
# 2019-12-01  14289812  14807176  12660962  6626276  8914585       0
# 2020-01-01   4972074  11391979   9596229  5834792  3650543       0
# 2020-02-01  23522875   4874541   4993788  2757485  5236393       0
# 2020-03-01  25040023  17347968   6374132  3168658  6835417       0

# %%
# 컬럼 덧셈하여 결과를 새로운 컬럼으로
df['텔레콤_합계'] = df['SK텔레콤'] + df['KT']
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT    텔레콤_합계
# 2019-10-01  17213058  17695770   7691742  5811352  4966225  10777577
# 2019-11-01  15767139  18344561   9932071  5760428  2329041   8089469
# 2019-12-01  14289812  14807176  12660962  6626276  8914585  15540861
# 2020-01-01   4972074  11391979   9596229  5834792  3650543   9485335
# 2020-02-01  23522875   4874541   4993788  2757485  5236393   7993878
# 2020-03-01  25040023  17347968   6374132  3168658  6835417  10004075

# %%
df['전자_합계'] = df['삼성전자'] + df['LG전자']
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT    텔레콤_합계     전자_합계
# 2019-10-01  17213058  17695770   7691742  5811352  4966225  10777577  34908828
# 2019-11-01  15767139  18344561   9932071  5760428  2329041   8089469  34111700
# 2019-12-01  14289812  14807176  12660962  6626276  8914585  15540861  29096988
# 2020-01-01   4972074  11391979   9596229  5834792  3650543   9485335  16364053
# 2020-02-01  23522875   4874541   4993788  2757485  5236393   7993878  28397416
# 2020-03-01  25040023  17347968   6374132  3168658  6835417  10004075  42387991

# %% [markdown]
# ## 컬럼 단위 데이터 변경

# %%
# 모든 개별값을 100000으로 나눈 결과를 df에 할당
df = df / 100000.
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT     텔레콤_합계  \
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225  107.77577
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041   80.89469
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585  155.40861
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543   94.85335
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393   79.93878
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417  100.04075
#
#                 전자_합계
# 2019-10-01  349.08828
# 2019-11-01  341.11700
# 2019-12-01  290.96988
# 2020-01-01  163.64053
# 2020-02-01  283.97416
# 2020-03-01  423.87991

# %% [markdown]
# ## 컬럼 삭제
# df.drop() 사용하면서 축(axis)를 지정

# %%
# 특정 컬럼 삭제
df = df.drop('텔레콤_합계', axis=1)
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT      전자_합계
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225  349.08828
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041  341.11700
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585  290.96988
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543  163.64053
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393  283.97416
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417  423.87991

# %%
# del 명령으로 특정 컬럼 삭제
del df['전자_합계']
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %% [markdown]
# ## 부울 인덱스 (데이터 필터링)

# %%
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
df.삼성전자 < 150
# Out:
# 2019-10-01    False
# 2019-11-01    False
# 2019-12-01     True
# 2020-01-01     True
# 2020-02-01    False
# 2020-03-01    False
# Name: 삼성전자, dtype: bool

# %%
# '삼성전자'컬럼이 150초과인 행(row) 추출
df[df.삼성전자 < 150]
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543

# %%
df.삼성전자.mean()
# Out:
# 168.00830166666665

# %%
# 삼성전자 컬럼의 값이 평균보다 큰 행(row) 추출 
df[df.삼성전자 > df.삼성전자.mean()]
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225
# 2020-02-01  235.22875   48.74541  49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968  63.74132  31.68658  68.35417

# %% [markdown]
# ## 다수의 조건으로 필터링하기

# %%
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
(150 < df.삼성전자 ) & (df.삼성전자 < 200)
# Out:
# 2019-10-01     True
# 2019-11-01     True
# 2019-12-01    False
# 2020-01-01    False
# 2020-02-01    False
# 2020-03-01    False
# Name: 삼성전자, dtype: bool

# %%
df[(150 < df.삼성전자 ) & (df.삼성전자 < 200)]
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561  99.32071  57.60428  23.29041

# %% [markdown]
# ## df.query()
#
# ```python
# df.query('쿼리문자열')
# ```

# %%
df.query('150 < 삼성전자 < 200')
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561  99.32071  57.60428  23.29041

# %%
df.query('삼성전자 > 삼성전자.mean() and  LG전자 > LG전자.mean()')
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225
# 2020-03-01  250.40023  173.47968  63.74132  31.68658  68.35417

# %% [markdown]
# ## 데이터 소트하기

# %%
df.sort_index(ascending=False)
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225

# %%
df.sort_values(by='삼성전자', ascending=False)
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543

# %% [markdown]
# ## 차트 그리기 - df.plot()
#
# 폰트 설치 (한글 폰트가 없다면)
# * https://hangeul.naver.com/2017/nanum

# %%
# matplotlib 설정
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'Gulim'
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (10,6)

# %%
# 특정 컬럼만 지정해서 그리기
df[['삼성전자', 'LG전자']].plot()
# Out:
# <AxesSubplot:>

# %%
# 크기와 제목 지정하기
df.plot(figsize=(10,6), title='광고비(월별)')
# Out:
# <AxesSubplot:title={'center':'광고비(월별)'}>

# %%
# 막대 차트 그리기
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\plusjune\anaconda3\lib\site-packages (from pandas_datareader) (1.2.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\plusjune\anaconda3\lib\site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: lxml in c:\users\plusjune\anaconda3\lib\site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\plusjune\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\plusjune\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\plusjune\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\plusjune\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\plusjune\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\plusjune\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\plusjune\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\plusjune\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0

# %% [markdown]
# ## pandas_datareader
# https://pandas-datareader.readthedocs.io

# %% [markdown]
# 만일 pandas_datareader가 설치되어 있지 않다면,
#
# ```bash
# C:\users\plusjune> pip install pandas_datareader
# ```

# %% [markdown]
# ## FRED에서 환율 데이터 가져오기
# FRED는 세인트 루이스 연방준비은행((Federal Reserve Bank of St. Louis)에서 제공하는 경제 데이터(Economic Data) 입니다
#
# 1달러당 원화와 위엔화
# * https://fred.stlouisfed.org/series/DEXKOUS
# * https://fred.stlouisfed.org/series/DEXCHUS

# %%
import pandas_datareader as pdr

# FRED에서 달러당 원화환율 데이터 가져오기
df = pdr.DataReader('DEXKOUS', 'fred', '1995', '2021')
df
# Out:
#             DEXKOUS
# DATE
# 1995-01-02      NaN
# 1995-01-03   791.80
# 1995-01-04   791.60
# 1995-01-05   792.40
# 1995-01-06   792.70
# ...             ...
# 2020-12-28  1096.67
# 2020-12-29  1092.55
# 2020-12-30  1086.62
# 2020-12-31  1086.11
# 2021-01-01      NaN
#
# [6785 rows x 1 columns]

# %%
import pandas_datareader as pdr

# 달러당원화환율(DEXKOUS), 달러당 위엔화환율(DEXCHUS)
df = pdr.DataReader(['DEXKOUS', 'DEXCHUS'], 'fred', '1995')
df
# Out:
#             DEXKOUS  DEXCHUS
# DATE
# 1995-01-02      NaN      NaN
# 1995-01-03   791.80   8.4647
# 1995-01-04   791.60   8.4647
# 1995-01-05   792.40   8.4630
# 1995-01-06   792.70   8.4626
# ...             ...      ...
# 2022-06-06  1253.52   6.6534
# 2022-06-07  1255.32   6.6675
# 2022-06-08  1253.50   6.6825
# 2022-06-09  1256.91   6.6915
# 2022-06-10  1268.01   6.7081
#
# [7160 rows x 2 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df.plot(secondary_y='DEXCHUS')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ## 엑셀 파일로 쓰기/읽기

# %%
# 엑셀로 저장
df.to_excel('exchanges.xlsx')

# 엑셀 파일 읽기
df = pd.read_excel('exchanges.xlsx', index_col='DATE')
df
# Out:
#             DEXKOUS  DEXCHUS
# DATE
# 1995-01-02      NaN      NaN
# 1995-01-03   791.80   8.4647
# 1995-01-04   791.60   8.4647
# 1995-01-05   792.40   8.4630
# 1995-01-06   792.70   8.4626
# ...             ...      ...
# 2022-06-06  1253.52   6.6534
# 2022-06-07  1255.32   6.6675
# 2022-06-08  1253.50   6.6825
# 2022-06-09  1256.91   6.6915
# 2022-06-10  1268.01   6.7081
#
# [7160 rows x 2 columns]

# %% [markdown]
# ## CSV 파일로 쓰기/읽기

# %%
# CSV 저장
df.to_csv('exchanges.csv')

# CSV 파일 읽기
df = pd.read_csv('exchanges.csv', index_col='DATE')
df
# Out:
#             DEXKOUS  DEXCHUS
# DATE
# 1995-01-02      NaN      NaN
# 1995-01-03   791.80   8.4647
# 1995-01-04   791.60   8.4647
# 1995-01-05   792.40   8.4630
# 1995-01-06   792.70   8.4626
# ...             ...      ...
# 2022-06-06  1253.52   6.6534
# 2022-06-07  1255.32   6.6675
# 2022-06-08  1253.50   6.6825
# 2022-06-09  1256.91   6.6915
# 2022-06-10  1268.01   6.7081
#
# [7160 rows x 2 columns]
